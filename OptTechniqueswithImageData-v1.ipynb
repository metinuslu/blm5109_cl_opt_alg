# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, clone_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# ## Download dataset and pre processing

# %%
# CIFAR-10 veri setini yüklüyoruz
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
#  CIFAR-10 veri kümesindeki 10 sınıfı sınıflandırmak için CNN mimarisi kullanılmıştır. CIFAR-10 veri kümesi, 32x32 çözünürlüğünde ve 3 kanallı (RGB) renklere sahip 10 sınıf içerir.

# %%
# CIFAR-10 sınıf isimleri
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
# Görselleştirecek örnek sayısı
num_examples = 12

plt.figure(figsize=(10, 5))
for i in range(num_examples):
    plt.subplot(3, 4, i + 1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Veri tipini float32'ye çevir ve normalizasyon yapıyoruz
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Sınıf etiketlerini one-hot encoding yapıyoruz
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# CNN Mimarisi
# - 1.Katman: 32 filtre kullanarak 3x3 boyutunda bir kernel uygular. 'relu' aktivasyon fonksiyonu kullanılır.
# - 2.Katman: İlk katmanın çıkışını girdi olarak alır daha derin özellikler çıkarır.
# - MaxPooling: 2x2 havuzlama, boyut azaltma.
# - Dropout: Eğitim sırasında %25 oranında nöronları rastgele devre dışı bırakır (overfitting önleme).
# - 3.Katman: 64 filtre kullanarak daha fazla özellik çıkarır.
# - 4.Katman: Ardışık Conv2D katmanları ile özellik çıkarımı güçlendirilir.
# - MaxPooling: 2x2 havuzlama, boyut azaltma.
# - Dropout: Yine %25 oranında nöronları devre dışı bırakarak aşırı öğrenme ihtimalini azaltır.
# - Flatten: Çıkış verisini tek bir vektör haline getirir. Bu vektör, tam bağlantılı (Dense) katman için giriş olur.
# - Dense: 512 nöronlu fully connected katman.
# - Dropout: %50 oranında nöronları rastgele devre dışı bırakır. Modelin genelleme yeteneğini artırır.
# - Çıkış Katmanı: 10 sınıflı, 'softmax' ile her bir sınıfa ait olasılık tahmini.

# %%
def create_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
# 5 farklı başlangıç noktası oluşturuyoruz
initial_weights = []
for _ in range(5):
    model = create_model()
    initial_weights.append(model.get_weights())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)                   │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 28, 28, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 12, 12, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 10, 10, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 512)                 │         819,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 890,410 (3.40 MB)
#  Trainable params: 890,410 (3.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Optimizasyon algoritmaları ve parametreleri tanımlıyoruz
optimizer_configs = {
    'SGD': {'class': SGD, 'params': {'learning_rate': 0.01}},
    'SGD_momentum': {'class': SGD, 'params': {'learning_rate': 0.01, 'momentum': 0.9}},
    'Adam': {'class': Adam, 'params': {'learning_rate': 0.001}}
}

# %% [markdown]
# ### Optimizations Algorithms

# %%
# Eğitim parametrelerini tanımlıyoruz
batch_size = 32
epochs = 10

# Sonuçları saklamak için listeleri tutuyoruz
trajectories = {}
history_records = {}
time_records = {}

for opt_name, opt_config in optimizer_configs.items():
    print(f"\nOptimizasyon Algoritması: {opt_name}")
    trajectories[opt_name] = []
    history_records[opt_name] = []
    time_records[opt_name] = []
    for idx, w0 in enumerate(initial_weights):
        print(f"\nBaşlangıç Noktası: {idx+1}")
        # Modeli başlangıç ağırlıklarıyla yeniden oluştur
        model = create_model()
        model.set_weights(w0)

        # Her model için optimizer'ı yeniden oluştur #aynı optimizer'ı kullanırken hata verdiği için eklendi
        optimizer_class = opt_config['class']
        optimizer_params = opt_config['params']
        optimizer = optimizer_class(**optimizer_params)

        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        # Ağırlık yörüngelerini saklamak için liste tutuyoruz
        weight_trajectory = []
        epoch_times = []
        history = {'loss': [], 'accuracy': [], 'val_loss': [], 'val_accuracy': []}

        # **Başlangıç ağırlıklarını kaydet**
        initial_weights_vector = np.concatenate([w.flatten() for w in model.get_weights()])
        weight_trajectory.append(initial_weights_vector)

        for epoch in range(epochs):
            print(f"\n=== {opt_name} | Başlangıç Noktası {idx+1} | Epoch {epoch+1}/{epochs} ===")
            start_time = time.time()
            # Eğitimi bir epoch için gerçekleştir (her bir epoch sonunda ağırlıkları kaydedip eklemek için)
            model.fit(x_train, y_train, batch_size=batch_size, epochs=1, validation_data=(x_test, y_test), verbose=1)
            end_time = time.time()
            # Epoch süresini kaydet
            epoch_times.append(end_time - start_time)
            # Ağırlıkları kaydet
            weights = np.concatenate([w.flatten() for w in model.get_weights()])
            weight_trajectory.append(weights)
            # Kayıp ve doğruluğu kaydet
            loss, acc = model.evaluate(x_train, y_train, verbose=0)
            val_loss, val_acc = model.evaluate(x_test, y_test, verbose=0)
            history['loss'].append(loss)
            history['accuracy'].append(acc)
            history['val_loss'].append(val_loss)
            history['val_accuracy'].append(val_acc)

        # Sonuçları sakla
        trajectories[opt_name].append(np.array(weight_trajectory))
        history_records[opt_name].append(history)
        time_records[opt_name].append(np.array(epoch_times))
# Out:
# Optimizasyon Algoritması: SGD
#
# Başlangıç Noktası: 1
#
# === SGD | Başlangıç Noktası 1 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.1506 - loss: 2.2335 - val_accuracy: 0.3116 - val_loss: 1.9409
#
# === SGD | Başlangıç Noktası 1 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3234 - loss: 1.8477 - val_accuracy: 0.3937 - val_loss: 1.6817
#
# === SGD | Başlangıç Noktası 1 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3791 - loss: 1.6945 - val_accuracy: 0.4454 - val_loss: 1.5269
#
# === SGD | Başlangıç Noktası 1 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4214 - loss: 1.5813 - val_accuracy: 0.4729 - val_loss: 1.4521
#
# === SGD | Başlangıç Noktası 1 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4662 - loss: 1.4742 - val_accuracy: 0.5174 - val_loss: 1.3249
#
# === SGD | Başlangıç Noktası 1 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5001 - loss: 1.3878 - val_accuracy: 0.5557 - val_loss: 1.2561
#
# === SGD | Başlangıç Noktası 1 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5267 - loss: 1.3161 - val_accuracy: 0.5772 - val_loss: 1.1890
#
# === SGD | Başlangıç Noktası 1 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5464 - loss: 1.2698 - val_accuracy: 0.5894 - val_loss: 1.1532
#
# === SGD | Başlangıç Noktası 1 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5699 - loss: 1.2064 - val_accuracy: 0.5881 - val_loss: 1.1571
#
# === SGD | Başlangıç Noktası 1 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5872 - loss: 1.1584 - val_accuracy: 0.6217 - val_loss: 1.0848
#
# Başlangıç Noktası: 2
#
# === SGD | Başlangıç Noktası 2 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1619 - loss: 2.2110 - val_accuracy: 0.2892 - val_loss: 1.9907
#
# === SGD | Başlangıç Noktası 2 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3139 - loss: 1.8746 - val_accuracy: 0.4288 - val_loss: 1.5728
#
# === SGD | Başlangıç Noktası 2 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4002 - loss: 1.6348 - val_accuracy: 0.4613 - val_loss: 1.4683
#
# === SGD | Başlangıç Noktası 2 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4585 - loss: 1.4787 - val_accuracy: 0.5229 - val_loss: 1.3256
#
# === SGD | Başlangıç Noktası 2 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4930 - loss: 1.3965 - val_accuracy: 0.5529 - val_loss: 1.2522
#
# === SGD | Başlangıç Noktası 2 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5213 - loss: 1.3272 - val_accuracy: 0.5666 - val_loss: 1.2211
#
# === SGD | Başlangıç Noktası 2 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5502 - loss: 1.2620 - val_accuracy: 0.5916 - val_loss: 1.1424
#
# === SGD | Başlangıç Noktası 2 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5675 - loss: 1.2130 - val_accuracy: 0.6048 - val_loss: 1.1121
#
# === SGD | Başlangıç Noktası 2 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5827 - loss: 1.1629 - val_accuracy: 0.6341 - val_loss: 1.0466
#
# === SGD | Başlangıç Noktası 2 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6025 - loss: 1.1272 - val_accuracy: 0.6399 - val_loss: 1.0302
#
# Başlangıç Noktası: 3
#
# === SGD | Başlangıç Noktası 3 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1598 - loss: 2.2199 - val_accuracy: 0.2917 - val_loss: 1.9969
#
# === SGD | Başlangıç Noktası 3 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3108 - loss: 1.8904 - val_accuracy: 0.3901 - val_loss: 1.6702
#
# === SGD | Başlangıç Noktası 3 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3798 - loss: 1.6872 - val_accuracy: 0.4582 - val_loss: 1.4812
#
# === SGD | Başlangıç Noktası 3 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4349 - loss: 1.5497 - val_accuracy: 0.4955 - val_loss: 1.3817
#
# === SGD | Başlangıç Noktası 3 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4767 - loss: 1.4493 - val_accuracy: 0.5150 - val_loss: 1.3339
#
# === SGD | Başlangıç Noktası 3 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5035 - loss: 1.3815 - val_accuracy: 0.5320 - val_loss: 1.3197
#
# === SGD | Başlangıç Noktası 3 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5271 - loss: 1.3116 - val_accuracy: 0.5784 - val_loss: 1.1937
#
# === SGD | Başlangıç Noktası 3 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5526 - loss: 1.2542 - val_accuracy: 0.6095 - val_loss: 1.1142
#
# === SGD | Başlangıç Noktası 3 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5694 - loss: 1.2083 - val_accuracy: 0.6138 - val_loss: 1.1107
#
# === SGD | Başlangıç Noktası 3 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5863 - loss: 1.1653 - val_accuracy: 0.6213 - val_loss: 1.0614
#
# Başlangıç Noktası: 4
#
# === SGD | Başlangıç Noktası 4 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1554 - loss: 2.2293 - val_accuracy: 0.2812 - val_loss: 1.9933
#
# === SGD | Başlangıç Noktası 4 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.2981 - loss: 1.9145 - val_accuracy: 0.3721 - val_loss: 1.7164
#
# === SGD | Başlangıç Noktası 4 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3753 - loss: 1.7161 - val_accuracy: 0.4232 - val_loss: 1.5653
#
# === SGD | Başlangıç Noktası 4 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4257 - loss: 1.5810 - val_accuracy: 0.4688 - val_loss: 1.4727
#
# === SGD | Başlangıç Noktası 4 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4613 - loss: 1.4789 - val_accuracy: 0.5194 - val_loss: 1.3547
#
# === SGD | Başlangıç Noktası 4 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4976 - loss: 1.3918 - val_accuracy: 0.5371 - val_loss: 1.2910
#
# === SGD | Başlangıç Noktası 4 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5227 - loss: 1.3210 - val_accuracy: 0.5647 - val_loss: 1.2157
#
# === SGD | Başlangıç Noktası 4 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5415 - loss: 1.2820 - val_accuracy: 0.5810 - val_loss: 1.1707
#
# === SGD | Başlangıç Noktası 4 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5628 - loss: 1.2310 - val_accuracy: 0.5922 - val_loss: 1.1356
#
# === SGD | Başlangıç Noktası 4 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5798 - loss: 1.1840 - val_accuracy: 0.6018 - val_loss: 1.1321
#
# Başlangıç Noktası: 5
#
# === SGD | Başlangıç Noktası 5 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1603 - loss: 2.2178 - val_accuracy: 0.3380 - val_loss: 1.8814
#
# === SGD | Başlangıç Noktası 5 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3155 - loss: 1.8779 - val_accuracy: 0.3762 - val_loss: 1.7172
#
# === SGD | Başlangıç Noktası 5 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3913 - loss: 1.6616 - val_accuracy: 0.4654 - val_loss: 1.4738
#
# === SGD | Başlangıç Noktası 5 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4393 - loss: 1.5382 - val_accuracy: 0.4873 - val_loss: 1.4289
#
# === SGD | Başlangıç Noktası 5 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4848 - loss: 1.4325 - val_accuracy: 0.5271 - val_loss: 1.3089
#
# === SGD | Başlangıç Noktası 5 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5089 - loss: 1.3637 - val_accuracy: 0.5513 - val_loss: 1.2695
#
# === SGD | Başlangıç Noktası 5 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5329 - loss: 1.2978 - val_accuracy: 0.5721 - val_loss: 1.2363
#
# === SGD | Başlangıç Noktası 5 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5511 - loss: 1.2589 - val_accuracy: 0.6006 - val_loss: 1.1371
#
# === SGD | Başlangıç Noktası 5 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5719 - loss: 1.1957 - val_accuracy: 0.5941 - val_loss: 1.1476
#
# === SGD | Başlangıç Noktası 5 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5937 - loss: 1.1518 - val_accuracy: 0.6032 - val_loss: 1.1281
#
# Optimizasyon Algoritması: SGD_momentum
#
# Başlangıç Noktası: 1
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.2421 - loss: 2.0308 - val_accuracy: 0.4466 - val_loss: 1.5561
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4459 - loss: 1.5175 - val_accuracy: 0.5289 - val_loss: 1.3114
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5216 - loss: 1.3356 - val_accuracy: 0.5754 - val_loss: 1.1914
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5734 - loss: 1.1860 - val_accuracy: 0.6522 - val_loss: 0.9957
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6137 - loss: 1.0858 - val_accuracy: 0.6465 - val_loss: 0.9951
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6437 - loss: 1.0164 - val_accuracy: 0.6928 - val_loss: 0.8940
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6715 - loss: 0.9351 - val_accuracy: 0.6837 - val_loss: 0.8929
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6818 - loss: 0.9040 - val_accuracy: 0.6731 - val_loss: 0.9591
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6945 - loss: 0.8791 - val_accuracy: 0.7177 - val_loss: 0.8274
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7039 - loss: 0.8528 - val_accuracy: 0.7197 - val_loss: 0.8135
#
# Başlangıç Noktası: 2
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1994 - loss: 2.1249 - val_accuracy: 0.4364 - val_loss: 1.5425
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4294 - loss: 1.5478 - val_accuracy: 0.4953 - val_loss: 1.3890
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5088 - loss: 1.3700 - val_accuracy: 0.5964 - val_loss: 1.1475
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5560 - loss: 1.2476 - val_accuracy: 0.6194 - val_loss: 1.0742
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5904 - loss: 1.1462 - val_accuracy: 0.6323 - val_loss: 1.0452
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6322 - loss: 1.0447 - val_accuracy: 0.6738 - val_loss: 0.9318
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6514 - loss: 0.9947 - val_accuracy: 0.6604 - val_loss: 0.9600
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6674 - loss: 0.9522 - val_accuracy: 0.6853 - val_loss: 0.8963
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6881 - loss: 0.8966 - val_accuracy: 0.7048 - val_loss: 0.8541
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6871 - loss: 0.9026 - val_accuracy: 0.7234 - val_loss: 0.8036
#
# Başlangıç Noktası: 3
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.2225 - loss: 2.0738 - val_accuracy: 0.4465 - val_loss: 1.5154
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4474 - loss: 1.5196 - val_accuracy: 0.5419 - val_loss: 1.2934
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5347 - loss: 1.2947 - val_accuracy: 0.5754 - val_loss: 1.2091
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5836 - loss: 1.1697 - val_accuracy: 0.6380 - val_loss: 1.0311
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6225 - loss: 1.0591 - val_accuracy: 0.6715 - val_loss: 0.9471
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6399 - loss: 1.0122 - val_accuracy: 0.6843 - val_loss: 0.9120
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6632 - loss: 0.9635 - val_accuracy: 0.7078 - val_loss: 0.8577
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6774 - loss: 0.9205 - val_accuracy: 0.7024 - val_loss: 0.8706
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6909 - loss: 0.8812 - val_accuracy: 0.7027 - val_loss: 0.8505
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6933 - loss: 0.8725 - val_accuracy: 0.7041 - val_loss: 0.8515
#
# Başlangıç Noktası: 4
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.2380 - loss: 2.0456 - val_accuracy: 0.4432 - val_loss: 1.5378
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4333 - loss: 1.5435 - val_accuracy: 0.5277 - val_loss: 1.3296
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5251 - loss: 1.3185 - val_accuracy: 0.5972 - val_loss: 1.1352
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5783 - loss: 1.1821 - val_accuracy: 0.6541 - val_loss: 0.9839
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6220 - loss: 1.0700 - val_accuracy: 0.6527 - val_loss: 0.9916
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6540 - loss: 0.9836 - val_accuracy: 0.7022 - val_loss: 0.8651
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6687 - loss: 0.9518 - val_accuracy: 0.7046 - val_loss: 0.8423
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6856 - loss: 0.9065 - val_accuracy: 0.6963 - val_loss: 0.8679
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6956 - loss: 0.8682 - val_accuracy: 0.7166 - val_loss: 0.8194
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7020 - loss: 0.8498 - val_accuracy: 0.7201 - val_loss: 0.8168
#
# Başlangıç Noktası: 5
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.2365 - loss: 2.0498 - val_accuracy: 0.4559 - val_loss: 1.4884
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4539 - loss: 1.4956 - val_accuracy: 0.5446 - val_loss: 1.2642
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5325 - loss: 1.3044 - val_accuracy: 0.5888 - val_loss: 1.1428
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5875 - loss: 1.1571 - val_accuracy: 0.6351 - val_loss: 1.0335
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6203 - loss: 1.0628 - val_accuracy: 0.6735 - val_loss: 0.9426
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6499 - loss: 0.9962 - val_accuracy: 0.6538 - val_loss: 0.9604
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6727 - loss: 0.9308 - val_accuracy: 0.6977 - val_loss: 0.8699
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6856 - loss: 0.8996 - val_accuracy: 0.7208 - val_loss: 0.7990
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6975 - loss: 0.8576 - val_accuracy: 0.7144 - val_loss: 0.8305
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7016 - loss: 0.8423 - val_accuracy: 0.7284 - val_loss: 0.7911
#
# Optimizasyon Algoritması: Adam
#
# Başlangıç Noktası: 1
#
# === Adam | Başlangıç Noktası 1 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.3390 - loss: 1.7733 - val_accuracy: 0.5640 - val_loss: 1.2090
#
# === Adam | Başlangıç Noktası 1 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5720 - loss: 1.1993 - val_accuracy: 0.6398 - val_loss: 1.0155
#
# === Adam | Başlangıç Noktası 1 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6394 - loss: 1.0201 - val_accuracy: 0.6838 - val_loss: 0.9133
#
# === Adam | Başlangıç Noktası 1 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6731 - loss: 0.9369 - val_accuracy: 0.7153 - val_loss: 0.8165
#
# === Adam | Başlangıç Noktası 1 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6973 - loss: 0.8622 - val_accuracy: 0.7161 - val_loss: 0.8046
#
# === Adam | Başlangıç Noktası 1 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7182 - loss: 0.8001 - val_accuracy: 0.7319 - val_loss: 0.7703
#
# === Adam | Başlangıç Noktası 1 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7280 - loss: 0.7751 - val_accuracy: 0.7482 - val_loss: 0.7234
#
# === Adam | Başlangıç Noktası 1 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7408 - loss: 0.7382 - val_accuracy: 0.7405 - val_loss: 0.7621
#
# === Adam | Başlangıç Noktası 1 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7476 - loss: 0.7167 - val_accuracy: 0.7571 - val_loss: 0.7055
#
# === Adam | Başlangıç Noktası 1 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7594 - loss: 0.6891 - val_accuracy: 0.7494 - val_loss: 0.7474
#
# Başlangıç Noktası: 2
#
# === Adam | Başlangıç Noktası 2 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.3316 - loss: 1.7900 - val_accuracy: 0.5706 - val_loss: 1.2022
#
# === Adam | Başlangıç Noktası 2 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5595 - loss: 1.2318 - val_accuracy: 0.6301 - val_loss: 1.0436
#
# === Adam | Başlangıç Noktası 2 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6256 - loss: 1.0519 - val_accuracy: 0.6943 - val_loss: 0.8877
#
# === Adam | Başlangıç Noktası 2 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6638 - loss: 0.9503 - val_accuracy: 0.7021 - val_loss: 0.8539
#
# === Adam | Başlangıç Noktası 2 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6906 - loss: 0.8839 - val_accuracy: 0.7191 - val_loss: 0.8109
#
# === Adam | Başlangıç Noktası 2 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7103 - loss: 0.8364 - val_accuracy: 0.7228 - val_loss: 0.8012
#
# === Adam | Başlangıç Noktası 2 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7207 - loss: 0.7983 - val_accuracy: 0.7175 - val_loss: 0.8158
#
# === Adam | Başlangıç Noktası 2 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7290 - loss: 0.7624 - val_accuracy: 0.7326 - val_loss: 0.7657
#
# === Adam | Başlangıç Noktası 2 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7338 - loss: 0.7552 - val_accuracy: 0.7496 - val_loss: 0.7384
#
# === Adam | Başlangıç Noktası 2 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7488 - loss: 0.7151 - val_accuracy: 0.7565 - val_loss: 0.7081
#
# Başlangıç Noktası: 3
#
# === Adam | Başlangıç Noktası 3 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.3192 - loss: 1.8218 - val_accuracy: 0.5547 - val_loss: 1.2382
#
# === Adam | Başlangıç Noktası 3 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5479 - loss: 1.2545 - val_accuracy: 0.6419 - val_loss: 1.0142
#
# === Adam | Başlangıç Noktası 3 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6204 - loss: 1.0638 - val_accuracy: 0.6835 - val_loss: 0.8972
#
# === Adam | Başlangıç Noktası 3 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6638 - loss: 0.9583 - val_accuracy: 0.6881 - val_loss: 0.8795
#
# === Adam | Başlangıç Noktası 3 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6916 - loss: 0.8808 - val_accuracy: 0.7135 - val_loss: 0.8315
#
# === Adam | Başlangıç Noktası 3 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7098 - loss: 0.8261 - val_accuracy: 0.7353 - val_loss: 0.7765
#
# === Adam | Başlangıç Noktası 3 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7249 - loss: 0.7770 - val_accuracy: 0.7269 - val_loss: 0.7893
#
# === Adam | Başlangıç Noktası 3 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7367 - loss: 0.7479 - val_accuracy: 0.7211 - val_loss: 0.8148
#
# === Adam | Başlangıç Noktası 3 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7448 - loss: 0.7236 - val_accuracy: 0.7414 - val_loss: 0.7516
#
# === Adam | Başlangıç Noktası 3 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7490 - loss: 0.7077 - val_accuracy: 0.7527 - val_loss: 0.7276
#
# Başlangıç Noktası: 4
#
# === Adam | Başlangıç Noktası 4 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.3073 - loss: 1.8562 - val_accuracy: 0.5615 - val_loss: 1.2238
#
# === Adam | Başlangıç Noktası 4 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5547 - loss: 1.2417 - val_accuracy: 0.6217 - val_loss: 1.0617
#
# === Adam | Başlangıç Noktası 4 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6277 - loss: 1.0524 - val_accuracy: 0.6604 - val_loss: 0.9670
#
# === Adam | Başlangıç Noktası 4 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6646 - loss: 0.9470 - val_accuracy: 0.7120 - val_loss: 0.8198
#
# === Adam | Başlangıç Noktası 4 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6912 - loss: 0.8715 - val_accuracy: 0.7173 - val_loss: 0.8155
#
# === Adam | Başlangıç Noktası 4 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7097 - loss: 0.8250 - val_accuracy: 0.7314 - val_loss: 0.7700
#
# === Adam | Başlangıç Noktası 4 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7290 - loss: 0.7741 - val_accuracy: 0.7435 - val_loss: 0.7460
#
# === Adam | Başlangıç Noktası 4 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7379 - loss: 0.7528 - val_accuracy: 0.7472 - val_loss: 0.7367
#
# === Adam | Başlangıç Noktası 4 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7461 - loss: 0.7161 - val_accuracy: 0.7565 - val_loss: 0.6970
#
# === Adam | Başlangıç Noktası 4 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7583 - loss: 0.6836 - val_accuracy: 0.7520 - val_loss: 0.7161
#
# Başlangıç Noktası: 5
#
# === Adam | Başlangıç Noktası 5 | Epoch 1/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.3361 - loss: 1.7781 - val_accuracy: 0.5622 - val_loss: 1.2072
#
# === Adam | Başlangıç Noktası 5 | Epoch 2/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5649 - loss: 1.2188 - val_accuracy: 0.6485 - val_loss: 0.9943
#
# === Adam | Başlangıç Noktası 5 | Epoch 3/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6358 - loss: 1.0295 - val_accuracy: 0.6898 - val_loss: 0.8908
#
# === Adam | Başlangıç Noktası 5 | Epoch 4/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6722 - loss: 0.9297 - val_accuracy: 0.7137 - val_loss: 0.8201
#
# === Adam | Başlangıç Noktası 5 | Epoch 5/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6961 - loss: 0.8628 - val_accuracy: 0.7216 - val_loss: 0.7937
#
# === Adam | Başlangıç Noktası 5 | Epoch 6/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7141 - loss: 0.8078 - val_accuracy: 0.7187 - val_loss: 0.7969
#
# === Adam | Başlangıç Noktası 5 | Epoch 7/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7224 - loss: 0.7844 - val_accuracy: 0.7337 - val_loss: 0.7692
#
# === Adam | Başlangıç Noktası 5 | Epoch 8/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7343 - loss: 0.7471 - val_accuracy: 0.7449 - val_loss: 0.7259
#
# === Adam | Başlangıç Noktası 5 | Epoch 9/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7412 - loss: 0.7342 - val_accuracy: 0.7505 - val_loss: 0.7263
#
# === Adam | Başlangıç Noktası 5 | Epoch 10/10 ===
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7492 - loss: 0.7130 - val_accuracy: 0.7598 - val_loss: 0.6903

# %% [markdown]
# **learning_rate**: Öğrenme oranı, optimizasyon sürecinin adım büyüklüğünü belirler.learning_rate='auto' olarak ayarlandığında, t-SNE veri setinin
# boyutuna göre uygun bir öğrenme oranı seçer.

# %%
# TEST ET
# 7. Yörüngelerin t-SNE ile 2 Boyuta İndirgenmesi

# Tüm yörüngeleri birleştir
all_trajectories = []
labels = []

for idx in range(len(initial_weights)):
    for opt_name in optimizer_configs.keys():
        traj = trajectories[opt_name][idx]
        all_trajectories.append(traj)
        labels.append(opt_name)

# Yörüngeleri birleştir ve şekillendir
all_points = np.concatenate(all_trajectories, axis=0)

# t-SNE uygulaması
tsne = TSNE(n_components=2, random_state=42, perplexity=50, n_iter=1000, learning_rate='auto', init='pca', verbose=1)
tsne_results = tsne.fit_transform(all_points)

# Her yörüngenin başlangıç ve bitiş indekslerini bul
trajectory_lengths = [len(traj) for traj in all_trajectories]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 165 samples in 0.052s...
# [t-SNE] Computed neighbors for 165 samples in 15.053s...
# [t-SNE] Computed conditional probabilities for sample 165 / 165
# [t-SNE] Mean sigma: 29.696322
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 45.282646
# [t-SNE] KL divergence after 750 iterations: 0.054415

# %%
# TEST ET
# 8. Yörüngelerin Görselleştirilmesi

# Renkleri belirle
colors = {'SGD': 'r', 'SGD_momentum': 'g', 'Adam': 'b'}

plt.figure(figsize=(12, 8))

start_idx = 0
for i, (opt_name, traj_len) in enumerate(zip(labels, trajectory_lengths)):
    end_idx = start_idx + traj_len
    x = tsne_results[start_idx:end_idx, 0]
    y = tsne_results[start_idx:end_idx, 1]
    # Her yörüngeyi çiz
    plt.plot(x, y, color=colors[opt_name],marker='o', label=opt_name if i % 5 == 0 else "", alpha=0.7)
    start_idx = end_idx

# Legend'da sadece algoritmaları göstermek için benzersiz etiketleri alalım
handles, labels_unique = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels_unique, handles))
plt.legend(by_label.values(), by_label.keys())

plt.title('Optimizasyon Yörüngeleri')
plt.xlabel('t-SNE Bileşen 1')
plt.ylabel('t-SNE Bileşen 2')
plt.show()

# %%
# TEST ET
# 8. Yörüngelerin Görselleştirilmesi

# Renkleri belirle
colors = {'SGD': 'r', 'SGD_momentum': 'g', 'Adam': 'b'}

plt.figure(figsize=(12, 8))

start_idx = 0
for i, (opt_name, traj_len) in enumerate(zip(labels, trajectory_lengths)):
    end_idx = start_idx + traj_len
    x = tsne_results[start_idx:end_idx, 0]
    y = tsne_results[start_idx:end_idx, 1]
    # Her yörüngeyi çiz
    plt.plot(x, y, color=colors[opt_name], label=opt_name if i % 5 == 0 else "", alpha=0.7)
    start_idx = end_idx

# Legend'da sadece algoritmaları göstermek için benzersiz etiketleri alalım
handles, labels_unique = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels_unique, handles))
plt.legend(by_label.values(), by_label.keys())

plt.title('Optimizasyon Yörüngeleri')
plt.xlabel('t-SNE Bileşen 1')
plt.ylabel('t-SNE Bileşen 2')
plt.show()

# %%
# Epoch vs Loss
# Optimizasyon algoritmalarının isimlerini alıyoruz
optimizer_names = list(optimizer_configs.keys())

# 3 tane alt grafik
num_algorithms = len(optimizer_names)

# Alt grafiklerin boyutlarını ayarlıyoruz
fig, axes = plt.subplots(nrows=1, ncols=num_algorithms, figsize=(6*num_algorithms, 5), sharey=True)

# Eğer tek bir grafik varsa, axes'i liste haline getirelim
if num_algorithms == 1:
    axes = [axes]

for idx, opt_name in enumerate(optimizer_names):
    ax = axes[idx]
    # Her algoritma için tüm başlangıç noktalarındaki eğitim geçmişini çizeceğiz
    for history in history_records[opt_name]:
        # Eğitim kaybı (Train Loss)
        ax.plot(history['loss'], linestyle='-', color=colors[opt_name],
                label='Train' if history == history_records[opt_name][0] else "")
        # Doğrulama kaybı (Validation Loss)
        ax.plot(history['val_loss'], linestyle='--', color=colors[opt_name],
                label='Validation' if history == history_records[opt_name][0] else "")

    ax.set_title(f'{opt_name} - Epoch vs Loss')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
# Epoch vs Accuracy
# Alt grafiklerin boyutlarını ayarlıyoruz
fig, axes = plt.subplots(nrows=1, ncols=num_algorithms, figsize=(6*num_algorithms, 5), sharey=True)

# Eğer tek bir grafik varsa, axes'i liste haline getirelim
if num_algorithms == 1:
    axes = [axes]

for idx, opt_name in enumerate(optimizer_names):
    ax = axes[idx]
    # Her algoritma için tüm başlangıç noktalarındaki eğitim geçmişini çizeceğiz
    for history in history_records[opt_name]:
        # Eğitim doğruluğu (Train Accuracy)
        ax.plot(history['accuracy'], linestyle='-', color=colors[opt_name],
                label='Train' if history == history_records[opt_name][0] else "")
        # Doğrulama doğruluğu (Validation Accuracy)
        ax.plot(history['val_accuracy'], linestyle='--', color=colors[opt_name],
                label='Validation' if history == history_records[opt_name][0] else "")

    ax.set_title(f'{opt_name} - Epoch vs Accuracy')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
# Time vs Loss
# Alt grafiklerin boyutlarını ayarlıyoruz
fig, axes = plt.subplots(nrows=1, ncols=num_algorithms, figsize=(6*num_algorithms, 5), sharey=True)

# Eğer tek bir grafik varsa, axes'i liste haline getirelim
if num_algorithms == 1:
    axes = [axes]

for idx, opt_name in enumerate(optimizer_names):
    ax = axes[idx]
    # Her algoritma için tüm başlangıç noktalarındaki eğitim geçmişini çizeceğiz
    for idx_hist, (history, times) in enumerate(zip(history_records[opt_name], time_records[opt_name])):
        cumulative_times = np.cumsum(times)
        # Eğitim kaybı (Train Loss)
        ax.plot(cumulative_times, history['loss'], linestyle='-', color=colors[opt_name],
                label='Train' if idx_hist == 0 else "")
        # Doğrulama kaybı (Validation Loss)
        ax.plot(cumulative_times, history['val_loss'], linestyle='--', color=colors[opt_name],
                label='Validation' if idx_hist == 0 else "")

    ax.set_title(f'{opt_name} - Time vs Loss')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
#### Epoch vs Loss Grafiği (Tümü)

plt.figure(figsize=(12, 8))

for opt_name in optimizer_configs.keys():
    for history in history_records[opt_name]:
        # Eğitim kaybı (Train Loss)
        plt.plot(history['loss'], linestyle='-', color=colors[opt_name],
                 label=f"{opt_name} - Train" if history == history_records[opt_name][0] else "")
        # Doğrulama kaybı (Validation Loss)
        plt.plot(history['val_loss'], linestyle='--', color=colors[opt_name],
                 label=f"{opt_name} - Validation" if history == history_records[opt_name][0] else "")

plt.title('Epoch vs Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#### Time vs Loss Grafiği (TÜMÜ)

plt.figure(figsize=(12, 8))

for opt_name in optimizer_configs.keys():
    for idx, (history, times) in enumerate(zip(history_records[opt_name], time_records[opt_name])):
        cumulative_times = np.cumsum(times)
        # Eğitim kaybı (Train Loss)
        plt.plot(cumulative_times, history['loss'], linestyle='-', color=colors[opt_name],
                 label=f"{opt_name} - Train" if idx == 0 else "")
        # Doğrulama kaybı (Validation Loss)
        plt.plot(cumulative_times, history['val_loss'], linestyle='--', color=colors[opt_name],
                 label=f"{opt_name} - Validation" if idx == 0 else "")

plt.title('Time vs Loss')
plt.xlabel('Time (s)')
plt.ylabel('Loss')
plt.legend()
plt.show()
