# %% [markdown]
# # Opt. Techniques with Text Data

# %%
# NLP Multi-Class Classification with DNN using Opt. Alg.

# Datasets
#  - AG News Classification Dataset : https://www.kaggle.com/datasets/amananandrai/ag-news-classification-dataset & http://groups.di.unipi.it/~gulli/AG_corpus_of_news_articles.html

# Opt. Algorithms
    # - Stokastik Gradient Descent
    # - Stokastik Gradient Descent with Momentum
    # - Stokastik Adam

# AG News Dataset
    # - Class Index: Consists of 1-4 numbers which represents class of which 1-World, 2-Sports, 3-Business, 4-Sci/Tech
    # - Title: Contains Title of the Articles
    # - Description: Contains Description of the Articles
    # - Data Shape: Train: 120K & Test: 7600

# %% [markdown]
# ### Import Libraries

# %%
import os
import warnings

from src.utils import get_project_config
from src.utils import missing_values
import pandas as pd
from dotenv import load_dotenv

# %%
import time
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, clone_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam
# Out:
# 2024-11-18 20:45:45.490989: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-18 20:45:45.492844: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-18 20:45:45.525366: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-18 20:45:45.526579: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-18 20:45:46.036417: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

warnings.filterwarnings('ignore')

# %% [markdown]
# #### Set Path and Constant Values

# %%
# Set Constants
ROOT_PATH = os.getcwd()
CFG_PATH = os.path.join(ROOT_PATH, 'cfg')
DATA_PATH = os.path.join(ROOT_PATH, 'data')

# %%
# import tensorflow as tf
# tf.config.list_physical_devices('GPU')

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ### Import Dataset

# %%
df_train_data = pd.read_csv(os.path.join(DATA_PATH, "train.csv.zip"), compression='zip')
df_train_data.head()
# Out:
#    Class Index  \
# 0            3
# 1            3
# 2            3
# 3            3
# 4            3
#
#                                                                        Title  \
# 0                          Wall St. Bears Claw Back Into the Black (Reuters)
# 1                        Carlyle Looks Toward Commercial Aerospace (Reuters)
# 2                            Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3               Iraq Halts Oil Exports from Main Southern Pipeline (Reuters)
# 4  Oil prices soar to all-time record, posing new menace to US economy (AFP)
#
#                                                                                                                                                                                                               Description
# 0                                                                                                                          Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
# 1  Reuters - Private investment firm Carlyle Group,\which has a reputation for making well-timed and occasionally\controversial plays in the defense industry, has quietly placed\its bets on another part of the market.
# 2                                Reuters - Soaring crude prices plus worries\about the economy and the outlook for earnings are expected to\hang over the stock market next week during the depth of the\summer doldrums.
# 3                     Reuters - Authorities have halted oil export\flows from the main pipeline in southern Iraq after\intelligence showed a rebel militia could strike\infrastructure, an oil official said on Saturday.
# 4                                                        AFP - Tearaway world oil prices, toppling records and straining wallets, present a new economic menace barely three months before the US presidential elections.

# %%
df_test_data = pd.read_csv(os.path.join(DATA_PATH, "test.csv.zip"), compression='zip')
df_test_data.head()
# Out:
#    Class Index  \
# 0            3
# 1            4
# 2            4
# 3            4
# 4            4
#
#                                                                                     Title  \
# 0                                                       Fears for T N pension after talks
# 1  The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com)
# 2                                           Ky. Company Wins Grant to Study Peptides (AP)
# 3                                           Prediction Unit Helps Forecast Wildfires (AP)
# 4                                             Calif. Aims to Limit Farm-Related Smog (AP)
#
#                                                                                                                                                                                                                                                                         Description
# 0                                                                                                                                                   Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
# 1                                        SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# 2                                                            AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# 3  AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# 4                                                                                               AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.

# %%
df_train_data_orj = df_train_data.copy()
df_test_data_orj = df_test_data.copy()

# %% [markdown]
# ### Columns Transformation

# %%
df_data_list = [df_train_data, df_test_data]
class_map = {1:'World', 2:'Sports', 3:'Business', 4:'Sci/Tech'}

for df in df_data_list:
    # print("DataFrame Name:", df)
    df.columns = df.columns.str.replace(' ', '', regex=False)
    df['ClassName'] = df['ClassIndex'].map(class_map)

# %%
df_train_data['Text'] = df_train_data['Title'] + ' ' + df_train_data['Description']
df_test_data['Text'] = df_test_data['Title'] + ' ' + df_test_data['Description']

# %%
df_train_data.head()
# Out:
#    ClassIndex  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#
#                                                                        Title  \
# 0                          Wall St. Bears Claw Back Into the Black (Reuters)
# 1                        Carlyle Looks Toward Commercial Aerospace (Reuters)
# 2                            Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3               Iraq Halts Oil Exports from Main Southern Pipeline (Reuters)
# 4  Oil prices soar to all-time record, posing new menace to US economy (AFP)
#
#                                                                                                                                                                                                               Description  \
# 0                                                                                                                          Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
# 1  Reuters - Private investment firm Carlyle Group,\which has a reputation for making well-timed and occasionally\controversial plays in the defense industry, has quietly placed\its bets on another part of the market.
# 2                                Reuters - Soaring crude prices plus worries\about the economy and the outlook for earnings are expected to\hang over the stock market next week during the depth of the\summer doldrums.
# 3                     Reuters - Authorities have halted oil export\flows from the main pipeline in southern Iraq after\intelligence showed a rebel militia could strike\infrastructure, an oil official said on Saturday.
# 4                                                        AFP - Tearaway world oil prices, toppling records and straining wallets, present a new economic menace barely three months before the US presidential elections.
#
#   ClassName  \
# 0  Business
# 1  Business
# 2  Business
# 3  Business
# 4  Business
#
#                                                                                                                                                                                                                                                                          Text
# 0                                                                                                                            Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
# 1  Carlyle Looks Toward Commercial Aerospace (Reuters) Reuters - Private investment firm Carlyle Group,\which has a reputation for making well-timed and occasionally\controversial plays in the defense industry, has quietly placed\its bets on another part of the market.
# 2                                    Oil and Economy Cloud Stocks' Outlook (Reuters) Reuters - Soaring crude prices plus worries\about the economy and the outlook for earnings are expected to\hang over the stock market next week during the depth of the\summer doldrums.
# 3            Iraq Halts Oil Exports from Main Southern Pipeline (Reuters) Reuters - Authorities have halted oil export\flows from the main pipeline in southern Iraq after\intelligence showed a rebel militia could strike\infrastructure, an oil official said on Saturday.
# 4                                  Oil prices soar to all-time record, posing new menace to US economy (AFP) AFP - Tearaway world oil prices, toppling records and straining wallets, present a new economic menace barely three months before the US presidential elections.

# %% [markdown]
# ### Show Metadata, Shape, Statistics and Missing Table

# %%
df_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ClassIndex   120000 non-null  int64
#  1   Title        120000 non-null  object
#  2   Description  120000 non-null  object
#  3   ClassName    120000 non-null  object
#  4   Text         120000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.6+ MB

# %%
df_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ClassIndex   7600 non-null   int64
#  1   Title        7600 non-null   object
#  2   Description  7600 non-null   object
#  3   ClassName    7600 non-null   object
#  4   Text         7600 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 297.0+ KB

# %%
df_train_data.shape, df_test_data.shape
# Out:
# ((120000, 5), (7600, 5))

# %%
df_train_data['ClassIndex'].value_counts()
# Out:
# ClassIndex
# 3    30000
# 4    30000
# 2    30000
# 1    30000
# Name: count, dtype: int64

# %%
df_test_data['ClassIndex'].value_counts()
# Out:
# ClassIndex
# 3    1900
# 4    1900
# 2    1900
# 1    1900
# Name: count, dtype: int64

# %%
missing_values(df=df_train_data, threshold=0, asc_sorting=False)
# Out:
#              Count  Percent
# Columns
# ClassIndex       0      0.0
# Title            0      0.0
# Description      0      0.0
# ClassName        0      0.0
# Text             0      0.0

# %%
missing_values(df=df_test_data, threshold=0, asc_sorting=False)
# Out:
#              Count  Percent
# Columns
# ClassIndex       0      0.0
# Title            0      0.0
# Description      0      0.0
# ClassName        0      0.0
# Text             0      0.0

# %% [markdown]
# ### Text Data Preprocessing

# %% [markdown]
# #### Text Preprocess

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

# NLTK kaynaklarını indir
nltk.download('stopwords')
nltk.download('wordnet')

# HTML etiketlerini ve URL'leri temizleme fonksiyonu
def remove_html_urls(text):
    """HTML etiketlerini ve URL'leri kaldırır."""
    text = re.sub(r'<.*?>', '', text)  # HTML etiketlerini temizleme
    text = re.sub(r'http\S+|www\S+', '', text)  # URL'leri temizleme
    return text

# Ekstra boşlukları temizleme
def remove_extra_whitespace(text):
    """Metindeki gereksiz boşlukları kaldırır."""
    text = re.sub(r'\s+', ' ', text)  # Birden fazla boşluğu tek bir boşluğa dönüştürür
    return text.strip()  # Başlangıç ve sondaki boşlukları siler

# Expand correction (yaygın kısaltmaların düzeltilmesi)
def expand_contractions(text):
    """Yaygın İngilizce kısaltmaları açar."""
    contractions = {
        "i'm": "i am", "don't": "do not", "can't": "cannot", "won't": "will not",
        "it's": "it is", "he's": "he is", "she's": "she is", "they're": "they are",
        "we're": "we are", "you've": "you have", "i've": "i have", "that's": "that is",
        "there's": "there is", "couldn't": "could not", "shouldn't": "should not"
        # Burada gerekli kısaltmaları ekleyebilirsin
    }
    for contraction, expansion in contractions.items():
        text = text.replace(contraction, expansion)
    return text

# Preprocessing fonksiyonu
def preprocess_text(df:pd.DataFrame, column_name:str, lemmatize:bool=True, use_stemming:bool=False):
    # 1. Küçük harfe dönüştürme
    df[column_name] = df[column_name].str.lower()

    # 2. HTML etiketlerini ve URL'leri temizleme
    df[column_name] = df[column_name].apply(remove_html_urls)

    # 3. Ekstra boşlukları kaldırma
    df[column_name] = df[column_name].apply(remove_extra_whitespace)

    # 4. Kısaltmaları düzeltme
    df[column_name] = df[column_name].apply(expand_contractions)

    # 5. Özel karakterlerin ve sayıların temizlenmesi
    df[column_name] = df[column_name].str.replace(r'[^a-zA-Z\s]', '', regex=True)

    # 6. Stop words kaldırma
    stop_words = set(stopwords.words('english'))
    df[column_name] = df[column_name].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

    # 7. Lemmatization ya da Stemming
    if lemmatize:
        lemmatizer = WordNetLemmatizer()
        df[column_name] = df[column_name].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))
    elif use_stemming:
        stemmer = PorterStemmer()
        df[column_name] = df[column_name].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))

    return df
# Out:
# [nltk_data] Downloading package stopwords to /opt/app-
# [nltk_data]     root/src/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /opt/app-
# [nltk_data]     root/src/nltk_data...

# %%
df_train_data = preprocess_text(df=df_train_data, column_name="Text")
df_test_data = preprocess_text(df=df_test_data, column_name="Text")

# %%
df_train_data[['Title', 'Description', 'Text']].head(5)
# Out:
#                                                                        Title  \
# 0                          Wall St. Bears Claw Back Into the Black (Reuters)
# 1                        Carlyle Looks Toward Commercial Aerospace (Reuters)
# 2                            Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3               Iraq Halts Oil Exports from Main Southern Pipeline (Reuters)
# 4  Oil prices soar to all-time record, posing new menace to US economy (AFP)
#
#                                                                                                                                                                                                               Description  \
# 0                                                                                                                          Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
# 1  Reuters - Private investment firm Carlyle Group,\which has a reputation for making well-timed and occasionally\controversial plays in the defense industry, has quietly placed\its bets on another part of the market.
# 2                                Reuters - Soaring crude prices plus worries\about the economy and the outlook for earnings are expected to\hang over the stock market next week during the depth of the\summer doldrums.
# 3                     Reuters - Authorities have halted oil export\flows from the main pipeline in southern Iraq after\intelligence showed a rebel militia could strike\infrastructure, an oil official said on Saturday.
# 4                                                        AFP - Tearaway world oil prices, toppling records and straining wallets, present a new economic menace barely three months before the US presidential elections.
#
#                                                                                                                                                                                                                         Text
# 0                                                                                                               wall st bear claw back black reuters reuters shortsellers wall street dwindlingband ultracynics seeing green
# 1  carlyle look toward commercial aerospace reuters reuters private investment firm carlyle groupwhich reputation making welltimed occasionallycontroversial play defense industry quietly placedits bet another part market
# 2                                             oil economy cloud stock outlook reuters reuters soaring crude price plus worriesabout economy outlook earnings expected tohang stock market next week depth thesummer doldrums
# 3      iraq halt oil export main southern pipeline reuters reuters authority halted oil exportflows main pipeline southern iraq afterintelligence showed rebel militia could strikeinfrastructure oil official said saturday
# 4                         oil price soar alltime record posing new menace u economy afp afp tearaway world oil price toppling record straining wallet present new economic menace barely three month u presidential election

# %%
df_train_data.head(3)
# Out:
#    ClassIndex                                                Title  \
# 0           3    Wall St. Bears Claw Back Into the Black (Reuters)
# 1           3  Carlyle Looks Toward Commercial Aerospace (Reuters)
# 2           3      Oil and Economy Cloud Stocks' Outlook (Reuters)
#
#                                                                                                                                                                                                               Description  \
# 0                                                                                                                          Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
# 1  Reuters - Private investment firm Carlyle Group,\which has a reputation for making well-timed and occasionally\controversial plays in the defense industry, has quietly placed\its bets on another part of the market.
# 2                                Reuters - Soaring crude prices plus worries\about the economy and the outlook for earnings are expected to\hang over the stock market next week during the depth of the\summer doldrums.
#
#   ClassName  \
# 0  Business
# 1  Business
# 2  Business
#
#                                                                                                                                                                                                                         Text
# 0                                                                                                               wall st bear claw back black reuters reuters shortsellers wall street dwindlingband ultracynics seeing green
# 1  carlyle look toward commercial aerospace reuters reuters private investment firm carlyle groupwhich reputation making welltimed occasionallycontroversial play defense industry quietly placedits bet another part market
# 2                                             oil economy cloud stock outlook reuters reuters soaring crude price plus worriesabout economy outlook earnings expected tohang stock market next week depth thesummer doldrums

# %%
df_test_data.head(3)
# Out:
#    ClassIndex  \
# 0           3
# 1           4
# 2           4
#
#                                                                                     Title  \
# 0                                                       Fears for T N pension after talks
# 1  The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com)
# 2                                           Ky. Company Wins Grant to Study Peptides (AP)
#
#                                                                                                                                                                                                                                   Description  \
# 0                                                                                                             Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
# 1  SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# 2                      AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
#
#   ClassName  \
# 0  Business
# 1  Sci/Tech
# 2  Sci/Tech
#
#                                                                                                                                                                                                                                                          Text
# 0                                                                                                                                        fear n pension talk union representing worker turner newall say disappointed talk stricken parent firm federal mogul
# 1  race second private team set launch date human spaceflight spacecom spacecom toronto canada secondteam rocketeers competing million ansari x prize contest forprivately funded suborbital space flight officially announced firstlaunch date manned rocket
# 2                                                             ky company win grant study peptide ap ap company founded chemistry researcher university louisville grant develop method producing better peptide short chain amino acid building block protein

# %% [markdown]
# #### Tokenization & Padding

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_words = 10000
# max_length = 200 

# Prepare tokenizer for text processing
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(df_train_data['Description'])

# Convert texts to sequences
X_train = tokenizer.texts_to_sequences(df_train_data['Description'])
X_test = tokenizer.texts_to_sequences(df_test_data['Description'])

# Pad sequences to ensure uniform length
max_sequence_length = 100  # Adjust based on your dataset's text length

X_train = pad_sequences(X_train, maxlen=max_sequence_length)
X_test = pad_sequences(X_test, maxlen=max_sequence_length)

# %%
X_train[0].shape, X_train[1].shape, X_train[2].shape
# Out:
# ((100,), (100,), (100,))

# %%
X_test[0].shape, X_test[1].shape, X_test[2].shape
# Out:
# ((100,), (100,), (100,))

# %%
# Sınıf etiketlerini one-hot encoding yapıyoruz
y_train = to_categorical(df_train_data['ClassIndex'] - 1, num_classes=4)
y_test = to_categorical(df_test_data['ClassIndex'] - 1, num_classes=4)

# %% [markdown]
# ### Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Embedding, Flatten

def create_model(input_dim=10000, output_dim=4, input_length=max_sequence_length):
    model = Sequential([
        Embedding(input_dim=input_dim, output_dim=128, input_length=input_length),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(output_dim, activation='softmax')
    ])
    # model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# 5 farklı başlangıç noktası oluşturuyoruz

initial_weights = []
for _ in range(5):
    model = create_model()
    model.build(input_shape=(None, max_sequence_length))
    initial_weights.append(model.get_weights())
# Out:
# 2024-11-18 20:46:19.894841: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# initial_weights[0]
# len(initial_weights)

# %%
model.build(input_shape=(None, max_sequence_length))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 100, 128)          1280000
#
#  flatten_4 (Flatten)         (None, 12800)             0
#
#  dense_8 (Dense)             (None, 128)               1638528
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2,919,044
# Trainable params: 2,919,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Optimizasyon algoritmaları ve parametreleri tanımlıyoruz
optimizer_configs = {
    'SGD': {'class': SGD, 'params': {'learning_rate': 0.01}},
    'SGD_momentum': {'class': SGD, 'params': {'learning_rate': 0.01, 'momentum': 0.9}},
    'Adam': {'class': Adam, 'params': {'learning_rate': 0.001}}
}

# %% [markdown]
# ### Optimizations Algorithms

# %%
# Eğitim parametrelerini tanımlıyoruz
batch_size = 32
epochs = 10

# Sonuçları saklamak için listeleri tutuyoruz
trajectories = {}
history_records = {}
time_records = {}

for opt_name, opt_config in optimizer_configs.items():
    print(f"\nOptimizasyon Algoritması: {opt_name}")
    trajectories[opt_name] = []
    history_records[opt_name] = []
    time_records[opt_name] = []
    for idx, w0 in enumerate(initial_weights):
        print(f"\nBaşlangıç Noktası: {idx+1}")
        # Modeli başlangıç ağırlıklarıyla yeniden oluştur
        model = create_model()
        model.build(input_shape=(None, max_sequence_length))
        model.set_weights(w0)

        # Her model için optimizer'ı yeniden oluştur #aynı optimizer'ı kullanırken hata verdiği için eklendi
        optimizer_class = opt_config['class']
        optimizer_params = opt_config['params']
        optimizer = optimizer_class(**optimizer_params)

        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        # Ağırlık yörüngelerini saklamak için liste tutuyoruz
        weight_trajectory = []
        epoch_times = []
        history = {'loss': [], 'accuracy': [], 'val_loss': [], 'val_accuracy': []}

        # **Başlangıç ağırlıklarını kaydet**
        initial_weights_vector = np.concatenate([w.flatten() for w in model.get_weights()])
        weight_trajectory.append(initial_weights_vector)

        for epoch in range(epochs):
            print(f"\n=== {opt_name} | Başlangıç Noktası {idx+1} | Epoch {epoch+1}/{epochs} ===")
            start_time = time.time()
            # Eğitimi bir epoch için gerçekleştir (her bir epoch sonunda ağırlıkları kaydedip eklemek için)
            model.fit(X_train, y_train, batch_size=batch_size, epochs=1, validation_data=(X_test, y_test), verbose=1)
            end_time = time.time()
            # Epoch süresini kaydet
            epoch_times.append(end_time - start_time)
            # Ağırlıkları kaydet
            weights = np.concatenate([w.flatten() for w in model.get_weights()])
            weight_trajectory.append(weights)
            # Kayıp ve doğruluğu kaydet
            loss, acc = model.evaluate(X_train, y_train, verbose=0)
            val_loss, val_acc = model.evaluate(X_test, y_test, verbose=0)
            history['loss'].append(loss)
            history['accuracy'].append(acc)
            history['val_loss'].append(val_loss)
            history['val_accuracy'].append(val_acc)

        # Sonuçları sakla
        trajectories[opt_name].append(np.array(weight_trajectory))
        history_records[opt_name].append(history)
        time_records[opt_name].append(np.array(epoch_times))
# Out:
# Optimizasyon Algoritması: SGD
#
# Başlangıç Noktası: 1
#
# === SGD | Başlangıç Noktası 1 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.3726 - accuracy: 0.3041 - val_loss: 1.3452 - val_accuracy: 0.4118
#
# === SGD | Başlangıç Noktası 1 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.2515 - accuracy: 0.4420 - val_loss: 1.0753 - val_accuracy: 0.5924
#
# === SGD | Başlangıç Noktası 1 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.9197 - accuracy: 0.6382 - val_loss: 0.7319 - val_accuracy: 0.7421
#
# === SGD | Başlangıç Noktası 1 | Epoch 4/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.6411 - accuracy: 0.7710 - val_loss: 0.5385 - val_accuracy: 0.8178
#
# === SGD | Başlangıç Noktası 1 | Epoch 5/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.4945 - accuracy: 0.8314 - val_loss: 0.4396 - val_accuracy: 0.8509
#
# === SGD | Başlangıç Noktası 1 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.4232 - accuracy: 0.8582 - val_loss: 0.4021 - val_accuracy: 0.8641
#
# === SGD | Başlangıç Noktası 1 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3821 - accuracy: 0.8735 - val_loss: 0.3757 - val_accuracy: 0.8734
#
# === SGD | Başlangıç Noktası 1 | Epoch 8/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.3551 - accuracy: 0.8830 - val_loss: 0.3570 - val_accuracy: 0.8782
#
# === SGD | Başlangıç Noktası 1 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3342 - accuracy: 0.8901 - val_loss: 0.3454 - val_accuracy: 0.8824
#
# === SGD | Başlangıç Noktası 1 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3160 - accuracy: 0.8967 - val_loss: 0.3381 - val_accuracy: 0.8880
#
# Başlangıç Noktası: 2
#
# === SGD | Başlangıç Noktası 2 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.3716 - accuracy: 0.3067 - val_loss: 1.3465 - val_accuracy: 0.3839
#
# === SGD | Başlangıç Noktası 2 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.2532 - accuracy: 0.4533 - val_loss: 1.0649 - val_accuracy: 0.6136
#
# === SGD | Başlangıç Noktası 2 | Epoch 3/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.8813 - accuracy: 0.6681 - val_loss: 0.6768 - val_accuracy: 0.7762
#
# === SGD | Başlangıç Noktası 2 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.5933 - accuracy: 0.7932 - val_loss: 0.4950 - val_accuracy: 0.8342
#
# === SGD | Başlangıç Noktası 2 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.4635 - accuracy: 0.8419 - val_loss: 0.4223 - val_accuracy: 0.8553
#
# === SGD | Başlangıç Noktası 2 | Epoch 6/10 ===
# 3750/3750 [==============================] - 14s 4ms/step - loss: 0.4047 - accuracy: 0.8651 - val_loss: 0.3897 - val_accuracy: 0.8680
#
# === SGD | Başlangıç Noktası 2 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3706 - accuracy: 0.8779 - val_loss: 0.3653 - val_accuracy: 0.8757
#
# === SGD | Başlangıç Noktası 2 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3451 - accuracy: 0.8863 - val_loss: 0.3563 - val_accuracy: 0.8799
#
# === SGD | Başlangıç Noktası 2 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3249 - accuracy: 0.8934 - val_loss: 0.3497 - val_accuracy: 0.8829
#
# === SGD | Başlangıç Noktası 2 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3102 - accuracy: 0.8970 - val_loss: 0.3447 - val_accuracy: 0.8832
#
# Başlangıç Noktası: 3
#
# === SGD | Başlangıç Noktası 3 | Epoch 1/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 1.3697 - accuracy: 0.3117 - val_loss: 1.3383 - val_accuracy: 0.3786
#
# === SGD | Başlangıç Noktası 3 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.2084 - accuracy: 0.4838 - val_loss: 0.9977 - val_accuracy: 0.6343
#
# === SGD | Başlangıç Noktası 3 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.8323 - accuracy: 0.6880 - val_loss: 0.6555 - val_accuracy: 0.7697
#
# === SGD | Başlangıç Noktası 3 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.5750 - accuracy: 0.7989 - val_loss: 0.4894 - val_accuracy: 0.8353
#
# === SGD | Başlangıç Noktası 3 | Epoch 5/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.4571 - accuracy: 0.8450 - val_loss: 0.4198 - val_accuracy: 0.8576
#
# === SGD | Başlangıç Noktası 3 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3998 - accuracy: 0.8661 - val_loss: 0.3898 - val_accuracy: 0.8670
#
# === SGD | Başlangıç Noktası 3 | Epoch 7/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.3645 - accuracy: 0.8786 - val_loss: 0.3685 - val_accuracy: 0.8755
#
# === SGD | Başlangıç Noktası 3 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3405 - accuracy: 0.8871 - val_loss: 0.3510 - val_accuracy: 0.8791
#
# === SGD | Başlangıç Noktası 3 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3206 - accuracy: 0.8929 - val_loss: 0.3455 - val_accuracy: 0.8808
#
# === SGD | Başlangıç Noktası 3 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3055 - accuracy: 0.8999 - val_loss: 0.3296 - val_accuracy: 0.8892
#
# Başlangıç Noktası: 4
#
# === SGD | Başlangıç Noktası 4 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.3733 - accuracy: 0.3022 - val_loss: 1.3485 - val_accuracy: 0.3974
#
# === SGD | Başlangıç Noktası 4 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.2667 - accuracy: 0.4451 - val_loss: 1.0907 - val_accuracy: 0.5861
#
# === SGD | Başlangıç Noktası 4 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.9042 - accuracy: 0.6558 - val_loss: 0.6910 - val_accuracy: 0.7683
#
# === SGD | Başlangıç Noktası 4 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.6072 - accuracy: 0.7875 - val_loss: 0.5225 - val_accuracy: 0.8200
#
# === SGD | Başlangıç Noktası 4 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.4729 - accuracy: 0.8401 - val_loss: 0.4268 - val_accuracy: 0.8546
#
# === SGD | Başlangıç Noktası 4 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.4106 - accuracy: 0.8634 - val_loss: 0.3976 - val_accuracy: 0.8611
#
# === SGD | Başlangıç Noktası 4 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3728 - accuracy: 0.8761 - val_loss: 0.3745 - val_accuracy: 0.8726
#
# === SGD | Başlangıç Noktası 4 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3472 - accuracy: 0.8855 - val_loss: 0.3679 - val_accuracy: 0.8737
#
# === SGD | Başlangıç Noktası 4 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3272 - accuracy: 0.8918 - val_loss: 0.3425 - val_accuracy: 0.8843
#
# === SGD | Başlangıç Noktası 4 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3108 - accuracy: 0.8985 - val_loss: 0.3314 - val_accuracy: 0.8880
#
# Başlangıç Noktası: 5
#
# === SGD | Başlangıç Noktası 5 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.3737 - accuracy: 0.3018 - val_loss: 1.3508 - val_accuracy: 0.3413
#
# === SGD | Başlangıç Noktası 5 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.2702 - accuracy: 0.4437 - val_loss: 1.1000 - val_accuracy: 0.5974
#
# === SGD | Başlangıç Noktası 5 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.8946 - accuracy: 0.6699 - val_loss: 0.6766 - val_accuracy: 0.7759
#
# === SGD | Başlangıç Noktası 5 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.5871 - accuracy: 0.7997 - val_loss: 0.4873 - val_accuracy: 0.8342
#
# === SGD | Başlangıç Noktası 5 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.4590 - accuracy: 0.8464 - val_loss: 0.4368 - val_accuracy: 0.8483
#
# === SGD | Başlangıç Noktası 5 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.4015 - accuracy: 0.8665 - val_loss: 0.3866 - val_accuracy: 0.8689
#
# === SGD | Başlangıç Noktası 5 | Epoch 7/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.3671 - accuracy: 0.8792 - val_loss: 0.3838 - val_accuracy: 0.8647
#
# === SGD | Başlangıç Noktası 5 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3409 - accuracy: 0.8883 - val_loss: 0.3542 - val_accuracy: 0.8784
#
# === SGD | Başlangıç Noktası 5 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3224 - accuracy: 0.8941 - val_loss: 0.3419 - val_accuracy: 0.8813
#
# === SGD | Başlangıç Noktası 5 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3064 - accuracy: 0.8989 - val_loss: 0.3366 - val_accuracy: 0.8859
#
# Optimizasyon Algoritması: SGD_momentum
#
# Başlangıç Noktası: 1
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.8020 - accuracy: 0.6563 - val_loss: 0.4095 - val_accuracy: 0.8563
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3662 - accuracy: 0.8763 - val_loss: 0.3543 - val_accuracy: 0.8770
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 3/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.2998 - accuracy: 0.8989 - val_loss: 0.3245 - val_accuracy: 0.8889
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2535 - accuracy: 0.9131 - val_loss: 0.3271 - val_accuracy: 0.8875
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2112 - accuracy: 0.9277 - val_loss: 0.3380 - val_accuracy: 0.8886
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 6/10 ===
# 3750/3750 [==============================] - 14s 4ms/step - loss: 0.1737 - accuracy: 0.9391 - val_loss: 0.3651 - val_accuracy: 0.8862
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1380 - accuracy: 0.9513 - val_loss: 0.4177 - val_accuracy: 0.8729
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1079 - accuracy: 0.9620 - val_loss: 0.4461 - val_accuracy: 0.8779
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0849 - accuracy: 0.9701 - val_loss: 0.4894 - val_accuracy: 0.8799
#
# === SGD_momentum | Başlangıç Noktası 1 | Epoch 10/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.0673 - accuracy: 0.9767 - val_loss: 0.5113 - val_accuracy: 0.8801
#
# Başlangıç Noktası: 2
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.7808 - accuracy: 0.6682 - val_loss: 0.4004 - val_accuracy: 0.8643
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3679 - accuracy: 0.8759 - val_loss: 0.3674 - val_accuracy: 0.8736
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 3/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.2982 - accuracy: 0.8988 - val_loss: 0.3331 - val_accuracy: 0.8855
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2543 - accuracy: 0.9134 - val_loss: 0.3289 - val_accuracy: 0.8863
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2122 - accuracy: 0.9277 - val_loss: 0.3509 - val_accuracy: 0.8837
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1739 - accuracy: 0.9401 - val_loss: 0.3780 - val_accuracy: 0.8828
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1395 - accuracy: 0.9511 - val_loss: 0.4021 - val_accuracy: 0.8832
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1083 - accuracy: 0.9620 - val_loss: 0.4158 - val_accuracy: 0.8870
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0870 - accuracy: 0.9696 - val_loss: 0.4578 - val_accuracy: 0.8797
#
# === SGD_momentum | Başlangıç Noktası 2 | Epoch 10/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.0674 - accuracy: 0.9763 - val_loss: 0.5036 - val_accuracy: 0.8778
#
# Başlangıç Noktası: 3
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.7825 - accuracy: 0.6680 - val_loss: 0.4141 - val_accuracy: 0.8593
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3683 - accuracy: 0.8753 - val_loss: 0.3361 - val_accuracy: 0.8832
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2989 - accuracy: 0.8988 - val_loss: 0.3211 - val_accuracy: 0.8904
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2495 - accuracy: 0.9153 - val_loss: 0.3291 - val_accuracy: 0.8892
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2095 - accuracy: 0.9279 - val_loss: 0.3415 - val_accuracy: 0.8851
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1710 - accuracy: 0.9409 - val_loss: 0.3528 - val_accuracy: 0.8864
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1357 - accuracy: 0.9526 - val_loss: 0.3934 - val_accuracy: 0.8822
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1068 - accuracy: 0.9622 - val_loss: 0.4080 - val_accuracy: 0.8833
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0861 - accuracy: 0.9703 - val_loss: 0.4761 - val_accuracy: 0.8786
#
# === SGD_momentum | Başlangıç Noktası 3 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0673 - accuracy: 0.9764 - val_loss: 0.4655 - val_accuracy: 0.8774
#
# Başlangıç Noktası: 4
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.7602 - accuracy: 0.6828 - val_loss: 0.3922 - val_accuracy: 0.8647
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3609 - accuracy: 0.8777 - val_loss: 0.3340 - val_accuracy: 0.8851
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2972 - accuracy: 0.8985 - val_loss: 0.3572 - val_accuracy: 0.8804
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 4/10 ===
# 3750/3750 [==============================] - 14s 4ms/step - loss: 0.2485 - accuracy: 0.9148 - val_loss: 0.3332 - val_accuracy: 0.8896
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 5/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2104 - accuracy: 0.9264 - val_loss: 0.3546 - val_accuracy: 0.8855
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 6/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1692 - accuracy: 0.9408 - val_loss: 0.3745 - val_accuracy: 0.8821
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1365 - accuracy: 0.9525 - val_loss: 0.3907 - val_accuracy: 0.8825
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1060 - accuracy: 0.9623 - val_loss: 0.4434 - val_accuracy: 0.8753
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0838 - accuracy: 0.9705 - val_loss: 0.4804 - val_accuracy: 0.8768
#
# === SGD_momentum | Başlangıç Noktası 4 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0679 - accuracy: 0.9765 - val_loss: 0.5161 - val_accuracy: 0.8789
#
# Başlangıç Noktası: 5
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 1/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.7731 - accuracy: 0.6749 - val_loss: 0.3771 - val_accuracy: 0.8695
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 2/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.3629 - accuracy: 0.8770 - val_loss: 0.3621 - val_accuracy: 0.8704
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 3/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2962 - accuracy: 0.8989 - val_loss: 0.3500 - val_accuracy: 0.8786
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 4/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.2517 - accuracy: 0.9150 - val_loss: 0.3287 - val_accuracy: 0.8899
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 5/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.2107 - accuracy: 0.9280 - val_loss: 0.3667 - val_accuracy: 0.8820
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 6/10 ===
# 3750/3750 [==============================] - 16s 4ms/step - loss: 0.1721 - accuracy: 0.9410 - val_loss: 0.3629 - val_accuracy: 0.8853
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 7/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1383 - accuracy: 0.9524 - val_loss: 0.4072 - val_accuracy: 0.8808
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 8/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.1103 - accuracy: 0.9615 - val_loss: 0.4425 - val_accuracy: 0.8784
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 9/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0859 - accuracy: 0.9703 - val_loss: 0.5161 - val_accuracy: 0.8708
#
# === SGD_momentum | Başlangıç Noktası 5 | Epoch 10/10 ===
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.0674 - accuracy: 0.9767 - val_loss: 0.5224 - val_accuracy: 0.8757
#
# Optimizasyon Algoritması: Adam
#
# Başlangıç Noktası: 1
#
# === Adam | Başlangıç Noktası 1 | Epoch 1/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3756 - accuracy: 0.8673 - val_loss: 0.2877 - val_accuracy: 0.9028
#
# === Adam | Başlangıç Noktası 1 | Epoch 2/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.1912 - accuracy: 0.9345 - val_loss: 0.3241 - val_accuracy: 0.8955
#
# === Adam | Başlangıç Noktası 1 | Epoch 3/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0880 - accuracy: 0.9698 - val_loss: 0.4255 - val_accuracy: 0.8907
#
# === Adam | Başlangıç Noktası 1 | Epoch 4/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0525 - accuracy: 0.9829 - val_loss: 0.5507 - val_accuracy: 0.8863
#
# === Adam | Başlangıç Noktası 1 | Epoch 5/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0403 - accuracy: 0.9871 - val_loss: 0.6007 - val_accuracy: 0.8878
#
# === Adam | Başlangıç Noktası 1 | Epoch 6/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0330 - accuracy: 0.9894 - val_loss: 0.7486 - val_accuracy: 0.8818
#
# === Adam | Başlangıç Noktası 1 | Epoch 7/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0290 - accuracy: 0.9907 - val_loss: 0.8017 - val_accuracy: 0.8814
#
# === Adam | Başlangıç Noktası 1 | Epoch 8/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.8871 - val_accuracy: 0.8833
#
# === Adam | Başlangıç Noktası 1 | Epoch 9/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.9435 - val_accuracy: 0.8813
#
# === Adam | Başlangıç Noktası 1 | Epoch 10/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0212 - accuracy: 0.9924 - val_loss: 0.9782 - val_accuracy: 0.8839
#
# Başlangıç Noktası: 2
#
# === Adam | Başlangıç Noktası 2 | Epoch 1/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3813 - accuracy: 0.8649 - val_loss: 0.2898 - val_accuracy: 0.9033
#
# === Adam | Başlangıç Noktası 2 | Epoch 2/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.1962 - accuracy: 0.9330 - val_loss: 0.3290 - val_accuracy: 0.8951
#
# === Adam | Başlangıç Noktası 2 | Epoch 3/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0923 - accuracy: 0.9687 - val_loss: 0.4447 - val_accuracy: 0.8855
#
# === Adam | Başlangıç Noktası 2 | Epoch 4/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0531 - accuracy: 0.9828 - val_loss: 0.5609 - val_accuracy: 0.8880
#
# === Adam | Başlangıç Noktası 2 | Epoch 5/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0402 - accuracy: 0.9872 - val_loss: 0.6353 - val_accuracy: 0.8871
#
# === Adam | Başlangıç Noktası 2 | Epoch 6/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0333 - accuracy: 0.9893 - val_loss: 0.7320 - val_accuracy: 0.8822
#
# === Adam | Başlangıç Noktası 2 | Epoch 7/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 0.8362 - val_accuracy: 0.8811
#
# === Adam | Başlangıç Noktası 2 | Epoch 8/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 0.8419 - val_accuracy: 0.8804
#
# === Adam | Başlangıç Noktası 2 | Epoch 9/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0234 - accuracy: 0.9922 - val_loss: 0.9243 - val_accuracy: 0.8818
#
# === Adam | Başlangıç Noktası 2 | Epoch 10/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 1.0142 - val_accuracy: 0.8811
#
# Başlangıç Noktası: 3
#
# === Adam | Başlangıç Noktası 3 | Epoch 1/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.3839 - accuracy: 0.8639 - val_loss: 0.2936 - val_accuracy: 0.8991
#
# === Adam | Başlangıç Noktası 3 | Epoch 2/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.1945 - accuracy: 0.9331 - val_loss: 0.3196 - val_accuracy: 0.8972
#
# === Adam | Başlangıç Noktası 3 | Epoch 3/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0915 - accuracy: 0.9689 - val_loss: 0.4396 - val_accuracy: 0.8914
#
# === Adam | Başlangıç Noktası 3 | Epoch 4/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0538 - accuracy: 0.9830 - val_loss: 0.5376 - val_accuracy: 0.8875
#
# === Adam | Başlangıç Noktası 3 | Epoch 5/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0390 - accuracy: 0.9874 - val_loss: 0.6516 - val_accuracy: 0.8841
#
# === Adam | Başlangıç Noktası 3 | Epoch 6/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.7587 - val_accuracy: 0.8854
#
# === Adam | Başlangıç Noktası 3 | Epoch 7/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0289 - accuracy: 0.9906 - val_loss: 0.8005 - val_accuracy: 0.8833
#
# === Adam | Başlangıç Noktası 3 | Epoch 8/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0263 - accuracy: 0.9913 - val_loss: 0.8410 - val_accuracy: 0.8820
#
# === Adam | Başlangıç Noktası 3 | Epoch 9/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0237 - accuracy: 0.9920 - val_loss: 0.9265 - val_accuracy: 0.8796
#
# === Adam | Başlangıç Noktası 3 | Epoch 10/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 1.0800 - val_accuracy: 0.8803
#
# Başlangıç Noktası: 4
#
# === Adam | Başlangıç Noktası 4 | Epoch 1/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3812 - accuracy: 0.8666 - val_loss: 0.2848 - val_accuracy: 0.9075
#
# === Adam | Başlangıç Noktası 4 | Epoch 2/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.1988 - accuracy: 0.9320 - val_loss: 0.3205 - val_accuracy: 0.8941
#
# === Adam | Başlangıç Noktası 4 | Epoch 3/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0965 - accuracy: 0.9676 - val_loss: 0.4158 - val_accuracy: 0.8899
#
# === Adam | Başlangıç Noktası 4 | Epoch 4/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0551 - accuracy: 0.9827 - val_loss: 0.5235 - val_accuracy: 0.8872
#
# === Adam | Başlangıç Noktası 4 | Epoch 5/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0413 - accuracy: 0.9868 - val_loss: 0.6295 - val_accuracy: 0.8868
#
# === Adam | Başlangıç Noktası 4 | Epoch 6/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0338 - accuracy: 0.9892 - val_loss: 0.6930 - val_accuracy: 0.8859
#
# === Adam | Başlangıç Noktası 4 | Epoch 7/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0284 - accuracy: 0.9907 - val_loss: 0.7543 - val_accuracy: 0.8889
#
# === Adam | Başlangıç Noktası 4 | Epoch 8/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.8127 - val_accuracy: 0.8832
#
# === Adam | Başlangıç Noktası 4 | Epoch 9/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.0229 - accuracy: 0.9922 - val_loss: 0.9360 - val_accuracy: 0.8837
#
# === Adam | Başlangıç Noktası 4 | Epoch 10/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 1.0512 - val_accuracy: 0.8833
#
# Başlangıç Noktası: 5
#
# === Adam | Başlangıç Noktası 5 | Epoch 1/10 ===
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3720 - accuracy: 0.8697 - val_loss: 0.2934 - val_accuracy: 0.8991
#
# === Adam | Başlangıç Noktası 5 | Epoch 2/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.1918 - accuracy: 0.9343 - val_loss: 0.3332 - val_accuracy: 0.8963
#
# === Adam | Başlangıç Noktası 5 | Epoch 3/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0893 - accuracy: 0.9700 - val_loss: 0.4289 - val_accuracy: 0.8905
#
# === Adam | Başlangıç Noktası 5 | Epoch 4/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0551 - accuracy: 0.9818 - val_loss: 0.5584 - val_accuracy: 0.8841
#
# === Adam | Başlangıç Noktası 5 | Epoch 5/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0386 - accuracy: 0.9873 - val_loss: 0.6526 - val_accuracy: 0.8843
#
# === Adam | Başlangıç Noktası 5 | Epoch 6/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0334 - accuracy: 0.9891 - val_loss: 0.7518 - val_accuracy: 0.8829
#
# === Adam | Başlangıç Noktası 5 | Epoch 7/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.7904 - val_accuracy: 0.8876
#
# === Adam | Başlangıç Noktası 5 | Epoch 8/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0262 - accuracy: 0.9910 - val_loss: 0.8547 - val_accuracy: 0.8812
#
# === Adam | Başlangıç Noktası 5 | Epoch 9/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.9416 - val_accuracy: 0.8809
#
# === Adam | Başlangıç Noktası 5 | Epoch 10/10 ===
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.0222 - accuracy: 0.9921 - val_loss: 0.9988 - val_accuracy: 0.8805

# %% [markdown]
# ### t-SNE

# %% [markdown]
# **learning_rate**: Öğrenme oranı, optimizasyon sürecinin adım büyüklüğünü belirler.learning_rate='auto' olarak ayarlandığında, t-SNE veri setinin
# boyutuna göre uygun bir öğrenme oranı seçer.

# %% [markdown]
# #### Dimention Reduction

# %%
# 7. Yörüngelerin t-SNE ile 2 Boyuta İndirgenmesi

# Tüm yörüngeleri birleştir
all_trajectories = []
labels = []

for idx in range(len(initial_weights)):
    for opt_name in optimizer_configs.keys():
        traj = trajectories[opt_name][idx]
        all_trajectories.append(traj)
        labels.append(opt_name)

# Yörüngeleri birleştir ve şekillendir
all_points = np.concatenate(all_trajectories, axis=0)

# t-SNE uygulaması
# n_iter=1000
tsne = TSNE(n_components=2, random_state=42, perplexity=50, n_iter=1000, learning_rate='auto', init='pca', verbose=1)
tsne_results = tsne.fit_transform(all_points)

# Her yörüngenin başlangıç ve bitiş indekslerini bul
trajectory_lengths = [len(traj) for traj in all_trajectories]
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 165 samples in 0.307s...
# [t-SNE] Computed neighbors for 165 samples in 13.253s...
# [t-SNE] Computed conditional probabilities for sample 165 / 165
# [t-SNE] Mean sigma: 39.194502
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.709904
# [t-SNE] KL divergence after 1000 iterations: 0.215354

# %% [markdown]
# #### Dimension Visualization

# %%
# 8. Yörüngelerin Görselleştirilmesi

# Renkleri belirle
colors = {'SGD': 'r', 'SGD_momentum': 'g', 'Adam': 'b'}

plt.figure(figsize=(12, 8))

start_idx = 0
for i, (opt_name, traj_len) in enumerate(zip(labels, trajectory_lengths)):
    end_idx = start_idx + traj_len
    x = tsne_results[start_idx:end_idx, 0]
    y = tsne_results[start_idx:end_idx, 1]
    # Her yörüngeyi çiz
    plt.plot(x, y, color=colors[opt_name],marker='o', label=opt_name if i % 5 == 0 else "", alpha=0.7)
    start_idx = end_idx

# Legend'da sadece algoritmaları göstermek için benzersiz etiketleri alalım
handles, labels_unique = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels_unique, handles))
plt.legend(by_label.values(), by_label.keys())

plt.title('Optimizasyon Yörüngeleri')
plt.xlabel('t-SNE Bileşen 1')
plt.ylabel('t-SNE Bileşen 2')
plt.show()

# %% [markdown]
# ### Epoch vs Loss

# %%
# Epoch vs Loss
# Optimizasyon algoritmalarının isimlerini alıyoruz
optimizer_names = list(optimizer_configs.keys())

# 3 tane alt grafik
num_algorithms = len(optimizer_names)

# Alt grafiklerin boyutlarını ayarlıyoruz
fig, axes = plt.subplots(nrows=1, ncols=num_algorithms, figsize=(6*num_algorithms, 5), sharey=True)

# Eğer tek bir grafik varsa, axes'i liste haline getirelim
if num_algorithms == 1:
    axes = [axes]

for idx, opt_name in enumerate(optimizer_names):
    ax = axes[idx]
    # Her algoritma için tüm başlangıç noktalarındaki eğitim geçmişini çizeceğiz
    for history in history_records[opt_name]:
        # Eğitim kaybı (Train Loss)
        ax.plot(history['loss'], linestyle='-', color=colors[opt_name],
                label='Train' if history == history_records[opt_name][0] else "")
        # Doğrulama kaybı (Validation Loss)
        ax.plot(history['val_loss'], linestyle='--', color=colors[opt_name],
                label='Validation' if history == history_records[opt_name][0] else "")

    ax.set_title(f'{opt_name} - Epoch vs Loss')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Epoch vs Accuracy

# %%
# Epoch vs Accuracy
# Alt grafiklerin boyutlarını ayarlıyoruz
fig, axes = plt.subplots(nrows=1, ncols=num_algorithms, figsize=(6*num_algorithms, 5), sharey=True)

# Eğer tek bir grafik varsa, axes'i liste haline getirelim
if num_algorithms == 1:
    axes = [axes]

for idx, opt_name in enumerate(optimizer_names):
    ax = axes[idx]
    # Her algoritma için tüm başlangıç noktalarındaki eğitim geçmişini çizeceğiz
    for history in history_records[opt_name]:
        # Eğitim doğruluğu (Train Accuracy)
        ax.plot(history['accuracy'], linestyle='-', color=colors[opt_name],
                label='Train' if history == history_records[opt_name][0] else "")
        # Doğrulama doğruluğu (Validation Accuracy)
        ax.plot(history['val_accuracy'], linestyle='--', color=colors[opt_name],
                label='Validation' if history == history_records[opt_name][0] else "")

    ax.set_title(f'{opt_name} - Epoch vs Accuracy')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Time vs Loss

# %%
# Time vs Loss
# Alt grafiklerin boyutlarını ayarlıyoruz
fig, axes = plt.subplots(nrows=1, ncols=num_algorithms, figsize=(6*num_algorithms, 5), sharey=True)

# Eğer tek bir grafik varsa, axes'i liste haline getirelim
if num_algorithms == 1:
    axes = [axes]

for idx, opt_name in enumerate(optimizer_names):
    ax = axes[idx]
    # Her algoritma için tüm başlangıç noktalarındaki eğitim geçmişini çizeceğiz
    for idx_hist, (history, times) in enumerate(zip(history_records[opt_name], time_records[opt_name])):
        cumulative_times = np.cumsum(times)
        # Eğitim kaybı (Train Loss)
        ax.plot(cumulative_times, history['loss'], linestyle='-', color=colors[opt_name],
                label='Train' if idx_hist == 0 else "")
        # Doğrulama kaybı (Validation Loss)
        ax.plot(cumulative_times, history['val_loss'], linestyle='--', color=colors[opt_name],
                label='Validation' if idx_hist == 0 else "")

    ax.set_title(f'{opt_name} - Time vs Loss')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Time vs Loss (All)

# %%
#### Epoch vs Loss Grafiği (Tümü)

plt.figure(figsize=(12, 8))

for opt_name in optimizer_configs.keys():
    for history in history_records[opt_name]:
        # Eğitim kaybı (Train Loss)
        plt.plot(history['loss'], linestyle='-', color=colors[opt_name],
                 label=f"{opt_name} - Train" if history == history_records[opt_name][0] else "")
        # Doğrulama kaybı (Validation Loss)
        plt.plot(history['val_loss'], linestyle='--', color=colors[opt_name],
                 label=f"{opt_name} - Validation" if history == history_records[opt_name][0] else "")

plt.title('Epoch vs Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Time vs Loss (All)

# %%
#### Time vs Loss Grafiği (TÜMÜ)

plt.figure(figsize=(12, 8))

for opt_name in optimizer_configs.keys():
    for idx, (history, times) in enumerate(zip(history_records[opt_name], time_records[opt_name])):
        cumulative_times = np.cumsum(times)
        # Eğitim kaybı (Train Loss)
        plt.plot(cumulative_times, history['loss'], linestyle='-', color=colors[opt_name],
                 label=f"{opt_name} - Train" if idx == 0 else "")
        # Doğrulama kaybı (Validation Loss)
        plt.plot(cumulative_times, history['val_loss'], linestyle='--', color=colors[opt_name],
                 label=f"{opt_name} - Validation" if idx == 0 else "")

plt.title('Time vs Loss')
plt.xlabel('Time (s)')
plt.ylabel('Loss')
plt.legend()
plt.show()
